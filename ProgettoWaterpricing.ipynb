# %% [markdown]
# # Water pricing

# %% [markdown]
# Water pricing is the most important and the simples instrument to encourage a more efficient use of irrigation in crop production.
#
# In a study publisched in 2015 by the University of Xin Jiang, Hohenheim and the Julius Kuhn-Institut analyze how it's possible to model a Bayesian Network to improve the water usage by variating the water price.
#
# The study was done to improve the water usage in Northwest China, in the Tarim River basin who suffers of extreme water drought's periods.

# %%
import numpy as np
import pandas as pd
from pgmpy.models import BayesianNetwork
from pgmpy.inference import VariableElimination
from pgmpy.models import BayesianModel
import networkx as nx
import matplotlib.pyplot as plt
from pgmpy.base import DAG
wPrice="WaterPrice"
dUse="Domestic use"
subsidy="Subsidy"
aGS="Agricultural management"
lessIdoTecniques="Production"
wUseEff="Water efficiency"

# %%
Water_price_model=BayesianNetwork([(wPrice,dUse),(wPrice,aGS),(subsidy,aGS),(aGS,lessIdoTecniques),
                                   (dUse,wUseEff),(lessIdoTecniques,wUseEff)])

nx_graph = nx.DiGraph(Water_price_model.edges())
position={
    wPrice:(3,10),
    subsidy:(10,10),
    dUse:(4,7),
    aGS:(8,7),
    lessIdoTecniques:(6,5),
    wUseEff:(5,3)
}
pos=nx.spring_layout(nx_graph,pos=position,fixed=[wPrice,subsidy],iterations=0)
#pos=nx.nx_pydot.pydot_layout(nx_graph)
nx.draw_networkx_nodes(nx_graph,pos,node_size=500)
nx.draw_networkx_edges(nx_graph,pos,edgelist=Water_price_model.edges(),edge_color="black")
nx.draw_networkx_labels(nx_graph,pos)
plt.show()

# %%
Water_price_model=BayesianNetwork([(wPrice,dUse),(wPrice,aGS),(subsidy,aGS),(aGS,lessIdoTecniques),
                                   (dUse,wUseEff),(lessIdoTecniques,wUseEff)])

from pgmpy.factors.discrete import TabularCPD
cpd_wPrice=TabularCPD(
    variable=wPrice,variable_card=2,values=[[0.5],[0.5]]
)
cpd_subsidy=TabularCPD(
    variable=subsidy, variable_card=2,values=[[0.2],[0.8]]
)
cpd_duse=TabularCPD(
    variable=dUse, variable_card=2,values=[[0.2,0.6],[0.8,0.4]],evidence=[wPrice],evidence_card=[2]
)
cpd_aGS=TabularCPD(
    variable=aGS,variable_card=2,values=[[0.98,0.4,1,0.01],[0.02,0.6,0,0.99]],evidence=[wPrice,subsidy],evidence_card=[2,2]
)
cpd_lessIdoTecniques=TabularCPD(
    variable=lessIdoTecniques,variable_card=2,values=[[0.7,0.3],[0.3,0.7]],evidence=[aGS],evidence_card=[2]
)
cpd_waterUseEff=TabularCPD(
    variable=wUseEff,variable_card=3,values=[[0.4,0.05,0.7,0.2],[0.4,0.1,0.25,0.3],[0.2,0.85,0.05,0.5]], evidence=[dUse,lessIdoTecniques],evidence_card=[2,2]
)


Water_price_model.add_cpds(
    cpd_wPrice,cpd_subsidy,cpd_duse,cpd_aGS,cpd_lessIdoTecniques,cpd_waterUseEff
)

# %%
Water_price_model.check_model()
# Out:
# True

# %% [markdown]
# #### Visualize the CPDs

# %%
for cpd in Water_price_model.get_cpds():
    print("CPD of {variable}".format(variable=cpd.variable))
    print(cpd)
# Out:
# CPD of WaterPrice
# +---------------+-----+
# | WaterPrice(0) | 0.5 |
# +---------------+-----+
# | WaterPrice(1) | 0.5 |
# +---------------+-----+
# CPD of Subsidy
# +------------+-----+
# | Subsidy(0) | 0.2 |
# +------------+-----+
# | Subsidy(1) | 0.8 |
# +------------+-----+
# CPD of Domestic use
# +-----------------+---------------+---------------+
# | WaterPrice      | WaterPrice(0) | WaterPrice(1) |
# +-----------------+---------------+---------------+
# | Domestic use(0) | 0.2           | 0.6           |
# +-----------------+---------------+---------------+
# | Domestic use(1) | 0.8           | 0.4           |
# +-----------------+---------------+---------------+
# CPD of Agricultural management
# +----------------------------+-----+---------------+---------------+
# | WaterPrice                 | ... | WaterPrice(1) | WaterPrice(1) |
# +----------------------------+-----+---------------+---------------+
# | Subsidy                    | ... | Subsidy(0)    | Subsidy(1)    |
# +----------------------------+-----+---------------+---------------+
# | Agricultural management(0) | ... | 1.0           | 0.01          |
# +----------------------------+-----+---------------+---------------+
# | Agricultural management(1) | ... | 0.0           | 0.99          |
# +----------------------------+-----+---------------+---------------+
# CPD of Production
# +-------------------------+-----+----------------------------+
# | Agricultural management | ... | Agricultural management(1) |
# +-------------------------+-----+----------------------------+
# | Production(0)           | ... | 0.3                        |
# +-------------------------+-----+----------------------------+
# | Production(1)           | ... | 0.7                        |
# +-------------------------+-----+----------------------------+
# CPD of Water efficiency
# +---------------------+-----+-----------------+
# | Domestic use        | ... | Domestic use(1) |
# +---------------------+-----+-----------------+
# | Production          | ... | Production(1)   |
# +---------------------+-----+-----------------+
# | Water efficiency(0) | ... | 0.2             |
# +---------------------+-----+-----------------+
# | Water efficiency(1) | ... | 0.3             |
# +---------------------+-----+-----------------+
# | Water efficiency(2) | ... | 0.5             |
# +---------------------+-----+-----------------+

# %% [markdown]
# ### Network domain analisys.

# %%
Water_inference = VariableElimination(Water_price_model)

# %% [markdown]
# Water domestic use i's not indipendet from less indrofile tecniques beacuse there's a flow of influence between them.

# %%
q_1=Water_inference.query([lessIdoTecniques],{dUse:0});
q_2=Water_inference.query([lessIdoTecniques],{dUse:1});
print(q_1==q_2)#must return false
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# False

# %% [markdown]
# Domestic usage must be indipendent from Subsidy because there is are two unmarked v-structures between them.

# %%
q_3=Water_inference.query([subsidy],{dUse:0});
q_4=Water_inference.query([subsidy],{dUse:1});
print(q_3==q_4)#must return true
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# True

# %% [markdown]
# Would have been different if we would have known a less usage of idro tenciques, thanks to the active v-structure.

# %%
q_5=Water_inference.query([subsidy],{dUse:0,lessIdoTecniques:0});
q_6=Water_inference.query([subsidy],{dUse:1,lessIdoTecniques:0});
print(q_5==q_6)#must return false
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# False

# %% [markdown]
# **Markow blancket** for a given node is made of his parents, his children and his childrens's parents and if this nodes are in the evidence, the given one is independant from all the others.
#
#  If we consider for example the variable ***Less hydropilic tecnologies*** the function markow blanket should return the variables:
#  - Agricultural management
#  - Water efficiency
#  - Domestical use

# %%
Water_price_model.get_markov_blanket(lessIdoTecniques)
# Out:
# ['Agricultural management', 'Water efficiency', 'Domestic use']

# %% [markdown]
# ### Observations

# %%
print("P=|(Water efficiency| Water pice=low,subsidy=yes)")
q_1=Water_inference.query([wUseEff],{ wPrice:0,subsidy:1})
print(q_1)
# Out:
# P=|(Water efficiency| Water pice=low,subsidy=yes)
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# +---------------------+-------------------------+
# | Water efficiency    |   phi(Water efficiency) |
# +=====================+=========================+
# | Water efficiency(0) |                  0.3862 |
# +---------------------+-------------------------+
# | Water efficiency(1) |                  0.2692 |
# +---------------------+-------------------------+
# | Water efficiency(2) |                  0.3446 |
# +---------------------+-------------------------+

# %%
print("P=|(Water efficiency| Water pice=high,subsidy=yes)")
q_1=Water_inference.query([wUseEff],{wPrice:1,subsidy:1})
print(q_1)
# Out:
# P=|(Water efficiency| Water pice=high,subsidy=yes)
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# +---------------------+-------------------------+
# | Water efficiency    |   phi(Water efficiency) |
# +=====================+=========================+
# | Water efficiency(0) |                  0.2346 |
# +---------------------+-------------------------+
# | Water efficiency(1) |                  0.2286 |
# +---------------------+-------------------------+
# | Water efficiency(2) |                  0.5367 |
# +---------------------+-------------------------+

# %% [markdown]
# ### Smapling method

# %%
from pgmpy.sampling import BayesianModelSampling
from pgmpy.factors.discrete import State
inference=VariableElimination(Water_price_model)
p_waterprice=Water_inference.query([wPrice],{lessIdoTecniques:1}).values[1]
p_waterprice2=Water_inference.query([wPrice],{lessIdoTecniques:1,dUse:0,subsidy:1,wUseEff:1}).values[1]
p_waterprice3=Water_inference.query([wPrice],{lessIdoTecniques:1,dUse:0,subsidy:1,wUseEff:1}).values[0]
inference=BayesianModelSampling(Water_price_model)


evidence1=[State(lessIdoTecniques,1)]
evidence2=[State(lessIdoTecniques,1),State(dUse,0),State(wUseEff,1),State(wPrice,1)]
evidence3=[State(lessIdoTecniques,1),State(dUse,0),State(wUseEff,1),State(subsidy,1)]
other=True
def prob_LW(samples,var_name):
    return np.sum((samples[str(var_name)]*samples['_weight']))/np.sum(samples['_weight'])

def err_rel(exact_value,approx_value):
    return np.abs((exact_value-approx_value)/exact_value)

def abs_err(exact_value,approx_value):
    return np.absolute(exact_value-approx_value)

def sampling_LW(size,ev,var_name,p_varname):
    sample_LW=inference.likelihood_weighted_sample(evidence=ev,
                                                        size=size,include_latents=False,show_progress=False)
    if other == False :
        p_LW=1-prob_LW(sample_LW,var_name)
    else:
        p_LW=prob_LW(sample_LW,var_name)
    return np.array([(size,p_LW,abs_err(p_varname,p_LW,))],
                    dtype=[("size","<i8"),("pwater_LW","<f8"),("err_LW","<f8")])
    
def sampling_RS(size,ev,var_name,p_varname):
    sample_RS=inference.rejection_sample(evidence=ev,
                                              size=size,include_latents=False,show_progress=False)  
    if other == False:
        p_RS=1-np.mean(sample_RS[var_name],axis=0)
    else:
        p_RS=np.mean(sample_RS[var_name],axis=0)
    return np.array([(size,p_RS,abs_err(p_varname,p_RS))],
                    dtype=[("size","<i8"),("pwater_RS","<f8"),("err_RS","<f8")])
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
starting_size_=1 # from 10 sample points
final_size=5   # to 10^5 sample points
experiments=20 # 8 experiments

# %%
result_LW=np.array([],dtype=[("size","<i8"),("pwater_LW","<f8"),("err_LW","<f8")])
for size in np.logspace(starting_size_, final_size,num=experiments, dtype='<i8'):
   result_LW=np.append(result_LW,sampling_LW(size,evidence1,wPrice,p_waterprice))

# %%
result_RS=np.array([],dtype=[("size","<i8"),("pwater_RS","<f8"),("err_RS","<f8")])
for size in np.logspace(starting_size_, final_size,num=experiments, dtype='<i8'):
   result_RS=np.append(result_RS,sampling_RS(size,evidence1,wPrice,p_waterprice))

# %%
val_piccolo=True
result_LS_ev3=np.array([],dtype=[("size","<i8"),("pwater_LW","<f8"),("err_LW","<f8")])
for size in np.logspace(starting_size_, final_size,num=experiments, dtype='<i8'):
   result_LS_ev3=np.append(result_LS_ev3,sampling_LW(size,evidence3,wPrice,p_waterprice2))

# %%
val_piccolo=False
result_LS_1ev3=np.array([],dtype=[("size","<i8"),("pwater_LW","<f8"),("err_LW","<f8")])
for size in np.logspace(starting_size_, final_size,num=experiments, dtype='<i8'):
   result_LS_1ev3=np.append(result_LS_1ev3,sampling_LW(size,evidence3,wPrice,p_waterprice3))

# %%
val_piccolo=True
results_RS_ev3=np.array([],dtype=[("size","<i8"),("pwater_RS","<f8"),("err_RS","<f8")])
for size in np.logspace(starting_size_, final_size,num=experiments, dtype='<i8'):
   results_RS_ev3=np.append(results_RS_ev3,sampling_RS(size,evidence3,wPrice,p_waterprice2))

# %%
val_piccolo=False
results_RS_1ev3=np.array([],dtype=[("size","<i8"),("pwater_RS","<f8"),("err_RS","<f8")])
for size in np.logspace(starting_size_, final_size,num=experiments, dtype='<i8'):
   results_RS_1ev3=np.append(results_RS_1ev3,sampling_RS(size,evidence3,wPrice,p_waterprice3))

# %%
plt.figure(figsize=(5,10))
plt.subplot(2,1,1)
plt.title("P=|(WP | DU=0, Agricultural management=1, S=1, WE=1)")
plt.xlabel("semple size")
plt.ylabel("Probability")
LWCplot, = plt.semilogx(result_LS_ev3["size"],result_LS_ev3["pwater_LW"],'blue',label="Likelihood Weighting")
RSCplot, = plt.semilogx(results_RS_ev3['size'],results_RS_ev3['pwater_RS'],'green',label="Rejection Sampling")
VECplot, = plt.semilogx(results_RS_ev3['size'],p_waterprice2*np.ones(results_RS_ev3.size),'r',label="reference value high")
LWCplot1, = plt.semilogx(result_LS_1ev3["size"],result_LS_1ev3["pwater_LW"],'blue')
RSCplot1, = plt.semilogx(results_RS_1ev3['size'],results_RS_1ev3['pwater_RS'],'green')
VECplot1, = plt.semilogx(results_RS_1ev3['size'],p_waterprice3*np.ones(results_RS_1ev3.size),'orange',label="reference value low")
plt.legend(handles=[LWCplot,RSCplot,VECplot,VECplot1])
plt.grid()
plt.subplot(2,1,2)
plt.title("Absolute error, WP=high")
plt.xlabel("semple size")
plt.ylabel("Absolute error")
ELWCplot, = plt.semilogx(result_LW['size'],result_LW['err_LW'],'b',label="LW abs err")
ERSCplot, = plt.semilogx(result_RS['size'],result_RS['err_RS'],'g',label="RS err")
plt.legend(handles=[ELWCplot,ERSCplot])
plt.grid()
plt.plot()
# Out:
# []
